# %% [markdown]
# # Laboratorium 4 - segmentacje
#
# ## Przygotowanie
#
#  * pobierz i wypakuj dataset: https://data.world/socialmediadata/beeradvocate
#  * [opcjonalnie] Utwórz wirtualne środowisko
#  `python3 -m venv ./recsyslab4`
#  * zainstaluj potrzebne biblioteki:
#  `pip install gensim==3.8.3 wordcloud==1.8.1`

# %% [markdown]
# ## Część 1. - przygotowanie danych

# %%
# importujemy potrzebne pakiety

from collections import Counter, defaultdict
import codecs
import csv

from gensim.corpora import Dictionary
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans, AgglomerativeClustering
from wordcloud import WordCloud

# %%
PATH = 'socialmediadata-beeradvocate/data/beer_reviews.csv'
SCORE_THRESHOLD = 4 # recenzje z co najmniej taka ocena wezmiemy pod uwage
VECTOR_SIZE = 20 # jak dlugie powinny byc wektory osadzen uzytkownikow
SEGMENTS_COUNT = 10 # na ile segmentow chcemy podzielic populacje uzytkownikow

# %%
# wczytujemy dane

def parse_headers(column_names):
    beer_id_column =  column_names.index('beer_beerid')
    beer_style_column = column_names.index('beer_style')
    user_id_column =  column_names.index('review_profilename')
    score_column =  column_names.index('review_overall')
    return beer_id_column, beer_style_column, user_id_column, score_column


def parse_review(line, beer_id_column, beer_style_column, user_id_column, score_column):
    return line[beer_id_column], line[beer_style_column], line[user_id_column], float(line[score_column])

def read_and_parse_reviews(path, score_threshold):
    with codecs.open(PATH, 'r', 'UTF-8') as datafile:
        datareader = csv.reader(datafile)
        beer_id_column, beer_style_column, user_id_column, score_column = parse_headers(next(datareader))
    
        users_favourite_beers = defaultdict(list)
        for review in datareader:
            beer_id, _, user_id, score = parse_review(review, beer_id_column, beer_style_column, user_id_column, score_column)
            if score >= score_threshold:
                users_favourite_beers[user_id].append(beer_id)

    return users_favourite_beers

def get_beer_id_to_style_mapping(path):
    with codecs.open(PATH, 'r', 'UTF-8') as datafile:
        datareader = csv.reader(datafile)
        beer_id_column, beer_style_column, user_id_column, score_column = parse_headers(next(datareader))
        beer_styles = {}
        for review in datareader:
            beer_id, beer_style, _, _ = parse_review(review, beer_id_column, beer_style_column, user_id_column, score_column)
            beer_styles[beer_id] = beer_style
        return beer_styles

# otrzymujemy slownik - mapowanie z user_id na liste ulubionych beer_ids
users_favourite_beers = read_and_parse_reviews(PATH, SCORE_THRESHOLD)

# dodatkowo przygotujmy sobie slownik mapujacy id piwa na nazwe stylu
beer_styles = get_beer_id_to_style_mapping(PATH)

# %% [markdown]
# ## Część 2. - osadzenia użytkowników

# %%
# trenujemy model osadzajacy piwa i uzytkownikow w przestrzeni

model = Word2Vec(sentences=users_favourite_beers.values(), vector_size=VECTOR_SIZE, window=5, min_count=1, workers=4)

# %%
# na podstawie modelu obliczamy wektorowa reprezentacje uzytkownikow

def get_mean_vector_for_user(user_favourite_beers, model, vector_size):
    # inicjalizujemy wektor zerami
    v = np.zeros(vector_size)
    
    # iterujemy po liscie user_favourite_beers, odczytujemy z modelu wektor reprezentujacy kazde piwo i dodajemy do wektora
    #   uzyj: model.wv[beer_id]
    # ...
    for beer in user_favourite_beers:
        v += model.wv[beer]
    
    # normalizujemy wektor - dzielimy kazda wspolrzedna przez liczbe piw
    # ...
    v = v/len(user_favourite_beers)
    
    return v
    


def get_mean_user_vectors(users_favourite_beers, model, vector_size):
    # korzystajac z powyzszej funkcji, tworzymy slownik {user_id -> vector}
    # ...
    mean_users_vectors = {key:get_mean_vector_for_user(value, model, vector_size) for key, value in users_favourite_beers.items()}
    
    return mean_users_vectors

user_vectors = get_mean_user_vectors(users_favourite_beers, model, VECTOR_SIZE)
# Out:
# {'johnmichaelsen': array([ 0.55736678,  0.28876057, -0.25127408,  0.33578699, -0.2185554 ,
#         -0.62237168, -0.55866952,  1.26709582, -0.17871535,  0.66685959,
#          0.22601737, -0.38636232,  0.13745967,  0.51919795,  0.64456608,
#          0.66796719,  0.29943712, -1.19464936, -0.52982996, -1.00912636]),
#  'LordAdmNelson': array([ 1.02623604,  0.31963699, -0.6055754 ,  0.59366299, -0.45666264,
#         -0.88618916, -0.74759021,  1.79552458,  0.2239857 ,  1.13976484,
#         -0.42474938, -0.67838143,  0.62616567,  0.89466947,  1.25022571,
#          1.09941221,  0.4112522 , -1.92274359, -0.88810271, -2.13868742]),
#  'augustgarage': array([ 0.83480271,  0.43092986, -0.26026317,  0.51156909, -0.24271983,
#         -0.76991668, -0.73914242,  1.47261033, -0.06484275,  0.833158  ,
#          0.45143969, -0.47686874,  0.28289563,  0.63053146,  0.76986062,
#          0.90495525,  0.28362597, -1.46124553, -0.69483478, -1.40245804]),
#  'MadeInOregon': array([ 0.69876939,  0.11469589, -0.77156966,  1.06493275,  0.49818757,
#         -0.7112133 , -0.44729942,  1.09282285, -0.43163893,  0.49806623,
#         -0.57571964, -1.00136559,  0.10428767,  0.54221913,  0.9964705 ,
#          0.76540186,  0.73629075, -1.303947  , -0.30681612, -1.36715672]),
#  'rawthar': array([ 1.20665759,  0.04923622, -0.47090411,  0.48263154, -1.18429028,
#         -0.71082191, -0.26262919,  1.17939943,  0.16716742,  1.59431532,
#         -0.3033806 , -0.06529351,  0.79068153,  0.28569085,  1.31415466,
#          0.97528921,  0.71606876, -1.70766054, -1.25611635, -1.91874935]),
#  'Halcyondays': array([ 0.54121696,  0.28812565, -0.18621884,  0.54853447, -0.12741304,
#         -0.64357924, -0.48887863,  1.16146826, -0.15605382,  0.66588074,
#          0.20016002, -0.53531086,  0.19634518,  0.4186585 ,  0.67336407,
#          0.64308367,  0.36393181, -1.34464829, -0.62744033, -1.10665201]),
#  'beerguy101': array([ 0.69998085,  0.30986671, -0.2070634 ,  0.83234566, -0.17748117,
#         -0.64229251, -0.45369151,  1.09376916, -0.14645143,  0.68538328,
#          0.12170503, -0.54390364,  0.48917474,  0.23040691,  0.84003833,
#          0.75808636,  0.42621518, -1.50347073, -0.63818926, -1.19998746]),
#  'UCLABrewN84': array([ 0.7479402 ,  0.21894101, -0.51391742,  0.55432048, -0.3943984 ,
#         -0.81684752, -0.75800242,  1.60300054,  0.10942583,  0.84159353,
#          0.04467959, -0.67934356,  0.33721799,  0.78241251,  1.03802984,
#          1.0011741 ,  0.39099759, -1.71872107, -0.8104965 , -1.73168828]),
#          0.00371925, -0.57191774,  0.27371782,  0.75593024,  0.93123383,
#          0.71295556,  0.32289196, -1.55752194, -0.78764761, -1.52311835]),
#  'chimney': array([ 1.00588108, -1.22188446, -0.09974472,  1.07231344, -0.87280572,
#         -1.33790507, -0.70020719,  1.11585468,  0.03321019,  1.1007391 ,
#         -0.89909344, -0.6643382 ,  0.31081169,  0.58306792,  1.32699493,
#          0.99615439,  0.3009748 , -1.25512906, -0.73625489, -2.28499477]),
#  'cooncat': array([ 0.73024075,  0.09524905, -0.66746991,  1.28477651, -0.11253342,
#         -0.95167351, -0.60435267,  2.02648363, -0.01102104,  0.94716219,
#         -0.95683769, -0.98992194,  0.43944438,  0.92613791,  1.0941121 ,
#          0.43709605,  0.53798109, -1.47780688, -0.69247789, -2.59177397]),
#  ...}

# %% [markdown]
# ## Część 3. - klasteryzacja

# %%
# klastrujemy uzytkownikow - mozemy uzyc wielu algorytmow, np k-means, agglomerative, BIRCH, ...

def get_users_segmentation(user_vectors, vector_size, segments_count, clustering_algorithm):
    # rozkladamy slownik user_vectors na liste uzytkownikow i liste wektorow
    #  - wazne jest zachowanie tej samej kolejnosci w obu listach
    users = list(user_vectors.keys())
    vectors = list(user_vectors.values())
    
    # zamieniamy liste wektorow w macierz
    users_array = np.stack(vectors, axis=0)
    # zaimplementuj wsparcie dla co najmniej jednego algorytmu wiecej
    if clustering_algorithm == 'agglomerative':
        clustering = AgglomerativeClustering(n_clusters=segments_count).fit_predict(users_array)
        # clustering to lista przypisanych klastrow - i-ty element to klaster, do ktorego nalezy i-ty wektor
    
    # jesli nie pomieszalismy kolejnosci w listach, to mozemy odzyskac mapping user_id -> cluster
    # ...
    segmentation = {key:value for (key, value) in zip(users, clustering)}
    
    return segmentation


segmentation = get_users_segmentation(user_vectors, VECTOR_SIZE, SEGMENTS_COUNT, 'agglomerative')

segmentation
# Out:
# {'johnmichaelsen': 3,
#  'LordAdmNelson': 3,
#  'augustgarage': 3,
#  'MadeInOregon': 3,
#  'rawthar': 3,
#  'Halcyondays': 3,
#  'beerguy101': 3,
#  'UCLABrewN84': 3,
#  'zaphodchak': 3,
#  'Tilley4': 3,
#  'mikedrinksbeer2': 3,
#  'dbmernin83': 3,
#  'titosupertramp': 3,
#  'optimator13': 3,
#  'Blakaeris': 3,
#  'bashiba': 3,
#  'Klym': 3,
#  'flexabull': 3,
#  'Bung': 3,
#  'oberon': 3,
#  't420o': 3,
#  'DarthKostrizer': 3,
#  'MrVonzipper': 3,
#  'TheWhiskerReview': 3,
#  'Jason': 3,
#  'DoubleJ': 3,
#  'Deuane': 3,
#  'Mattybeerguy': 5,
#  'micromaniac129': 3,
#  'northyorksammy': 3,
#  'vette2006c5r': 3,
#  'EvanEngelstad': 3,
#  'djeucalyptus': 3,
#  'ccrida': 3,
#  'brewandbbq': 3,
#  'hopsbreath': 3,
#  'Slatetank': 3,
#  'Proteus93': 3,
#  'SShelly': 3,
#  'zoso1967': 3,
#  'msubulldog25': 3,
#  'NJpadreFan': 3,
#  'd0ggnate': 3,
#  'Cyberkedi': 3,
#  'babyhobbes': 3,
#  'mdagnew': 3,
#  'mikesgroove': 3,
#  'hdofu': 3,
#  'GratefulBeerGuy': 3,
#  'PDXHops': 3,
#  'IMincedTheKing': 3,
#  'Goliath': 3,
#  'zeff80': 3,
#  'akorsak': 3,
#  'wchesak': 3,
#  'bfields4': 3,
#  'dyan': 3,
#  'HopDerek': 3,
#  'mtrentm': 3,
#  'maximum12': 3,
#  'JayQue': 3,
#  'bbothen': 3,
#  'Kegatron': 3,
#  'CrellMoset': 3,
#  'joepais': 3,
#  'BeerSox': 3,
#  'gford217': 3,
#  'thehand': 3,
#  'GbVDave': 3,
#  'Beejay': 3,
#  'SurlyDuff': 3,
#  'Wetpaperbag': 3,
#  'largadeer': 3,
#  'elniko': 3,
#  'deltatauhobbit': 3,
#  'woemad': 3,
#  'czechsaaz': 3,
#  'Wasatch': 3,
#  'Urbancaver': 3,
#  'brentk56': 3,
#  'BeerZack': 3,
#  'russpowell': 3,
#  'Spikester': 3,
#  'Vancer': 3,
#  'ghostwalker': 3,
#  'udubdawg': 3,
#  'Bfarr': 3,
#  'cburian': 3,
#  'mnwags': 3,
#  'NeroFiddled': 3,
#  'IntriqKen': 3,
#  'lackenhauser': 3,
#  'kgotcher': 3,
#  'MLegendre': 3,
#  'ddarden': 3,
#  'ElGordo': 3,
#  'BuckeyeNation': 3,
#  'Reidrover': 3,
#  'BeerLover99': 3,
#  'BrewerB': 3,
#  'robwestcott': 3,
#  'ColForbinBC': 3,
#  'woosterbill': 3,
#  'ReelBigwigFish': 3,
#  'cbarrett4': 3,
#  'chodinheaven': 3,
#  'tempest': 3,
#  'jeff1973': 2,
#  'Duff27': 3,
#  'Scotchboy': 3,
#  'corby112': 3,
#  'youradhere': 3,
#  'FosterJM': 3,
#  'bobhits': 3,
#  'climax': 3,
#  'AEK': 3,
#  'wcudwight': 3,
#  'kzoobrew': 3,
#  'dudemuskie': 3,
#  'elgiacomo': 3,
#  'ArrogantB': 3,
#  'stephens101': 3,
#  'barleywinefiend': 3,
#  'merlin48': 3,
#  'cjever19': 3,
#  'ThreeWiseMen': 3,
#  'philbertk': 3,
#  'Brent': 3,
#  'BeerAdvocate': 3,
#  'mikereaser': 3,
#  'jkrich': 3,
#  'SpdKilz': 3,
#  'indiapaleale': 3,
#  'Cresant': 3,
#  'hosehead83': 3,
#  'kshankar': 3,
#  'bump8628': 3,
#  'WesWes': 3,
#  'ClockworkOrange': 3,
#  'organicbrewer': 3,
#  'onix1agr': 3,
#  'dedrinker': 3,
#  'woodychandler': 3,
#  'rfgetz': 3,
#  'JohnGalt1': 3,
#  'womencantsail': 3,
#  'ckeegan04': 3,
#  'WeisGuy': 3,
#  'Rmassimiano': 3,
#  'droomyster': 3,
#  'flagmantho': 3,
#  'snaotheus': 3,
#  'RoyalT': 3,
#  'philbe311': 3,
#  'CaptainIPA': 3,
#  'anchordrinker': 3,
#  'spointon': 3,
#  'Gavage': 3,
#  'Knapp85': 3,
#  'mjyoung': 3,
#  'vande': 3,
#  'pitasoup': 3,
#  'match1112': 3,
#  'sgsmfdoom': 3,
#  'Nashvillain': 3,
#  'CHILLINDYLAN': 3,
#  'emmasdad': 3,
#  'GarthDanielson': 3,
#  'Akfan': 3,
#  'chumba526': 3,
#  'coldriver': 3,
#  'Mora2000': 3,
#  'GRG1313': 3,
#  'Derek': 3,
#  'suncrust': 3,
#  'dc55110': 3,
#  'julian': 3,
#  'tdm168': 3,
#  'oglmcdgl': 3,
#  'kitty66': 3,
#  'Valevapor': 3,
#  'lowendfrequency': 3,
#  'vkv822': 3,
#  'bitterthebetter': 3,
#  'RedDiamond': 5,
#  'mcallister': 3,
#  'Crotor': 3,
#  'unklesyd': 3,
#  'freed': 3,
#  'inthebeeraisle': 3,
#  'brianairb85': 5,
#  'hippityhops85': 3,
#  'Rutager': 3,
#  'beerman207': 3,
#  'alabamatie': 3,
#  'bagpiper2005': 3,
#  'LukeD23': 3,
#  'PhageLab': 3,
#  'lnashsig': 3,
#  'mindlucent2007': 3,
#  'AlCaponeJunior': 3,
#  'BEERchitect': 3,
#  'Jayli': 3,
#  'clayrock81': 3,
#  'lstokes': 3,
#  'kylejohnson03': 3,
#  'csiewert': 3,
#  'beerphan': 3,
#  'JTahoe': 3,
#  'JoEBoBpr': 3,
#  'TheManiacalOne': 3,
#  'awalk1227': 3,
#  'BuckyFresh': 3,
#  'SamuelJackson45': 3,
#  'djbreezy': 3,
#  'JoeyBeerBelly': 3,
#  'DeanMoriarty': 3,
#  'xnicknj': 3,
#  'Beerenauslese': 3,
#  'BrewsB4Shrews': 3,
#  'cvaypai': 3,
#  'cbak999': 3,
#  'pigdog': 4,
#  'irishgurl4': 3,
#  'charmcityboh': 3,
#  'seedsofchaos': 3,
#  'JamesS': 3,
#  'Ryan011235': 3,
#  'samie85': 3,
#  'StaveHooks': 3,
#  'thecarster1': 3,
#  'GarrettMD': 3,
#  'leedorham': 3,
#  'hawks10': 3,
#  'Bubba83': 3,
#  'JohnQVegas': 3,
#  'sliverX': 3,
#  'bridgetowhophead': 3,
#  'TheHungryHiker': 3,
#  'nc41': 3,
#  'btorsdog': 3,
#  'jzeilinger': 3,
#  'gatornation': 3,
#  'squaremile': 3,
#  'thagr81us': 3,
#  'brauseboof': 3,
#  'BigMike': 3,
#  'trevorjn06': 3,
#  'therica': 3,
#  'WYVYRN527': 3,
#  'kiddynamite920': 3,
#  'olmatty': 3,
#  'scottyshades': 3,
#  'Freethyhops': 3,
#  'wolfinthemirror': 3,
#  'oregonskibum': 3,
#  'thain709': 3,
#  'gatorbreath': 3,
#  'branimal9': 3,
#  'cdizinno': 3,
#  'MacQ32': 3,
#  'beerdedking': 3,
#  'vicsju1991': 3,
#  'dbossman': 3,
#  'TheFightfan1': 3,
#  'drewba': 3,
#  'EricP': 5,
#  'IPAguy2009': 3,
#  'AlexJ': 3,
#  'avalon07': 3,
#  'jpro': 3,
#  'mdcrouser': 3,
#  'kylehayworth': 3,
#  'Kadonny': 3,
#  'RomaniIteDomum': 3,
#  'armock': 3,
#  'biggred1': 3,
#  'Casey10': 3,
#  'PeteVenkman': 3,
#  'callmemickey': 3,
#  'hoppyhobby': 3,
#  'Philabeerphia': 3,
#  'iasanlee': 3,
#  'MURF0320': 3,
#  'SpeedwayJim': 3,
#  'raverjames': 3,
#  'Lunch': 3,
#  'bamadog': 3,
#  'jwc215': 3,
#  'Gyle41386': 3,
#  'ShogoKawada': 3,
#  'alleykatking': 3,
#  'berebrando': 3,
#  'RedBrewer83': 3,
#  'slayer3604': 3,
#  'jctribe25': 3,
#  'DrDogbeer': 3,
#  'kels': 3,
#  'Primitivechef': 1,
#  'BevMoAndrew': 3,
#  'Finn': 3,
#  'drabmuh': 3,
#  'nickd717': 3,
#  'glid02': 3,
#  'mikey711': 3,
#  'Stimwizzle': 2,
#  'wmthorne': 3,
#  'mbunje': 3,
#  'hckyfn9999': 3,
#  'Imstillthegman': 3,
#  'qchic': 3,
#  'beerswamie': 3,
#  'Metalmonk': 3,
#  'webbcreative': 3,
#  'Tdizzle': 3,
#  'Docer': 3,
#  'jackorain': 3,
#  'meatyard': 3,
#  'tronester': 3,
#  'Seanibus': 3,
#  'Monkeyknife': 3,
#  'washburnkid': 3,
#  'jfitzy78': 3,
#  'skrib09': 3,
#  'mcsquint': 3,
#  'jtd1969': 3,
#  'Rhettroactive': 3,
#  'comfortablynumb1': 3,
#  'zoolzoo': 3,
#  'bosox941827': 3,
#  'doopydoogle': 3,
#  'wedge': 3,
#  'errantnight': 3,
#  'wnh': 3,
#  'dukew456': 3,
#  'sholland119': 3,
#  'beer2day': 3,
#  'HairOfTh3Dog': 3,
#  'dirtylou': 3,
#  'naterock': 3,
#  'SpecialK088': 3,
#  'jdense': 3,
#  'dakid618': 3,
#  'Tone': 3,
#  'pinotboy007': 3,
#  'blackie': 3,
#  'jdoncbus': 3,
#  'Jimbo87': 3,
#  'tpd975': 3,
#  'aforbes10': 3,
#  'timtim': 3,
#  'hopdog': 3,
#  'Chelsea1905': 3,
#  'MisterClean': 3,
#  'ThirstyHopHead': 3,
#  'aracauna': 3,
#  'pjwilson': 3,
#  'koopa': 3,
#  'DIM': 3,
#  'AKBelgianBeast': 3,
#  'beereality': 3,
#  'mnapier': 3,
#  'MiguelMandingo': 3,
#  'JDV': 3,
#  'kirok1999': 3,
#  'MuenchenerKindl': 3,
#  'libertygrails': 3,
#  'WVbeergeek': 3,
#  'unclederby': 3,
#  'Floydster': 3,
#  'Bierguy5': 3,
#  'blakesell': 3,
#  'cswhitehorse': 3,
#  'weeare138': 3,
#  'kevinmkirk': 3,
#  'genog': 3,
#  'franksnbeans': 3,
#  'bootylicious': 3,
#  'BerkeleyBeerMan': 3,
#  '9InchNails': 3,
#  'kingjames1': 3,
#  'Hopfenpeter': 3,
#  'Tucquan': 3,
#  'Ummagum': 3,
#  'peabody': 3,
#  'dcloeren': 3,
#  'KMcG': 3,
#  'unionturf': 3,
#  'NStLincoln': 3,
#  'CuttDeez': 3,
#  'SaCkErZ9': 3,
#  'Jenkster4': 3,
#  'litheum94': 3,
#  'Yagman3000': 3,
#  'cbros': 3,
#  'Georgiabeer': 3,
#  'IronLover': 3,
#  'chocosushi': 3,
#  'Thorpe429': 3,
#  'Schmit': 3,
#  'beagle75': 3,
#  'Dope': 3,
#  'seans86': 3,
#  'chugalug06': 3,
#  'JCaweinstein': 3,
#  'bluejacket74': 3,
#  'felipe2toes': 3,
#  'Nugganooch': 3,
#  'MaltsOfGlory': 3,
#  'robbrandes': 3,
#  'rootbeerman': 3,
#  'dubinsky': 3,
#  'TheSarge': 3,
#  'richkrull': 3,
#  'colts9016': 3,
#  'MTNboy': 3,
#  'shand': 3,
#  'haddon': 3,
#  'itsfreeasinbeer': 3,
#  'generalnotsew': 3,
#  'betsona': 3,
#  'whatthehull': 3,
#  'StoneTSR': 3,
#  'notchucknorris': 3,
#  'portia99': 3,
#  'u2carew': 3,
#  'Crabbicuss': 3,
#  'Rifugium': 3,
#  'Beerandraiderfan': 3,
#  'Bliss': 5,
#  'soju6': 3,
#  'css82420': 5,
#  'plaid75': 3,
#  'venneman': 5,
#  'Satchboogie': 3,
#  'JeffBob': 3,
#  'GreenCard': 3,
#  'rand': 3,
#  'Gobzilla': 3,
#  'jorg2619': 3,
#  'vince4953529': 3,
#  'baconbourbon': 3,
#  'grumpy': 5,
#  'pjbear05': 5,
#  'zeledonia': 3,
#  'tbraun1': 3,
#  'Flightoficarus': 3,
#  'morenone': 0,
#  'Offa': 3,
#  'tchenery': 3,
#  'brewdlyhooked13': 3,
#  'abrand': 3,
#  'seanbhudson': 3,
#  'fropones': 3,
#  'vacax': 3,
#  'tigerpaws': 3,
#  'BeerBelcher': 3,
#  'DiabolikDUB': 3,
#  'HuskyinPDX': 3,
#  'TheBeerCarl': 3,
#  'eatabagofbooger': 3,
#  'Absumaster': 3,
#  'BlackHaddock': 5,
#  'Mark': 3,
#  'kaseydad': 3,
#  'BigMcLargeHuge': 5,
#  'lou91': 3,
#  'isualum12': 3,
#  '4000qtrap': 3,
#  'hoegaardenhero': 3,
#  'Natural510': 3,
#  'Cobratrooper': 3,
#  'jjboesen': 3,
#  'seanyfo': 5,
#  'illidurit': 3,
#  'UncleJimbo': 3,
#  'tjsdomer2': 3,
#  'realbama': 3,
#  'FreshmanPour77': 3,
#  'CHickman': 3,
#  'tigg924': 3,
#  'archerwrestler': 5,
#  'birdypowder': 3,
#  'McKnightOwl': 3,
#  'Only23': 3,
#  'Hoagie1973': 3,
#  'Devilsfan87': 5,
#  'Mistofminn': 3,
#  'caskstrength': 3,
#  'gdfan47': 3,
#  'Beerfoo87': 5,
#  'bobsy': 3,
#  'ejthetiger': 5,
#  'GoodKnight1220': 3,
#  'jsdunlop': 3,
#  'cnally': 3,
#  'thechamp': 3,
#  'tardiffism': 2,
#  'gnargnar': 3,
#  'stanleykoolbrick': 3,
#  'BDIMike': 3,
#  'NascarJDS': 5,
#  'botham': 3,
#  'riemenschneider': 3,
#  'zuggy9': 3,
#  'jmbranum': 3,
#  'veech': 3,
#  'MusicmanSD': 3,
#  'robocrouch': 3,
#  'RBorsato': 3,
#  'Brew1Up': 1,
#  'palffyfan': 5,
#  'MrSeth': 3,
#  'doctorjoeyboey': 5,
#  'Hibernator': 3,
#  'Pepeton': 5,
#  'casualbeerman': 3,
#  'Likeburning': 3,
#  'AndreiX': 3,
#  'johnshuster': 5,
#  'tobyandgina': 3,
#  'ommegangpbr': 3,
#  'alankwak': 3,
#  'buxwheat': 3,
#  'rousee': 3,
#  'GCBrewingCo': 3,
#  'ski271': 3,
#  'samsneed': 5,
#  'sinkr': 5,
#  'BigRedN': 3,
#  'TheDeuce': 3,
#  'ThistleKing': 3,
#  'SepticDeath': 1,
#  'bierman2000': 3,
#  'Mustard': 3,
#  'EagleTalon': 3,
#  'fdoosey': 3,
#  'Beerbluesbiology': 2,
#  'gorilla19': 3,
#  'barknee': 3,
#  'NODAK': 3,
#  'vladimerjr': 3,
#  'kneeland': 3,
#  'eb003': 3,
#  'guitarcrazy3': 5,
#  'frankld2': 3,
#  'hoppheadIPA': 3,
#  'Tang07': 3,
#  'javajeep1972': 5,
#  'KingSpank': 2,
#  'EssexAleMan': 3,
#  'BucBasil': 3,
#  'rvdoorn': 3,
#  'EatsTacos': 3,
#  'bark': 5,
#  'gam3': 2,
#  'flatblack80': 3,
#  'Bionic': 3,
#  '67cuda': 3,
#  'ILJAY': 5,
#  'dbek': 3,
#  'CrazyDavros': 3,
#  'patto1ro': 5,
#  'charlatan': 3,
#  'kmacphail': 5,
#  'BSF': 3,
#  'foamer': 3,
#  'stcules': 5,
#  'GnomeKing': 3,
#  'blitheringidiot': 3,
#  'jALEson': 5,
#  'EwaldEichstaett': 3,
#  'beertunes': 3,
#  'ATPete': 3,
#  'tbeckett': 3,
#  'catrone': 3,
#  'schoolcb': 5,
#  '1fastz28': 3,
#  'danielocean03': 3,
#  'BlackAngus': 3,
#  'RustyShackleford': 3,
#  'Dogbrick': 3,
#  'baos': 3,
#  'ktrillionaire': 3,
#  '908carson': 3,
#  'FtownThrowDown': 3,
#  'zerk': 3,
#  'Brettster': 3,
#  'tmoneyba': 3,
#  'sprinkle': 3,
#  'beveritt': 3,
#  'brundo4': 3,
#  'thedrewski86': 3,
#  'rhoadsrage': 3,
#  'Ricochet': 3,
#  'Generik420': 3,
#  'Jon': 3,
#  'Viking': 3,
#  'mynie': 3,
#  'leftmindedrighty': 3,
#  'shbobdb': 3,
#  'Sephiroth': 3,
#  'Shades': 3,
#  'ReluctantScooper': 5,
#  'BrewIndy': 3,
#  'Tode': 3,
#  'smcolw': 3,
#  'Hojaminbag': 3,
#  'Ragingbull': 3,
#  'ChainGangGuy': 3,
#  'mnfinnkidd': 3,
#  'Graebner': 3,
#  'nadiezhda': 5,
#  'sinistrsam': 3,
#  'asabreed': 3,
#  'GusterFan': 3,
#  'jsanford': 3,
#  'MSchae1017': 3,
#  'metter98': 3,
#  'Aiptasia': 3,
#  'ChBass': 5,
#  'dmamiano': 3,
#  'fattyre': 3,
#  'Higravity': 3,
#  'Fenris244': 3,
#  'Brewski4Drewski': 3,
#  'G2Brew': 3,
#  'shockingbluerose': 5,
#  'mduncan': 3,
#  'charlesbyrd': 3,
#  'smibroncos': 3,
#  'Mickelswit': 3,
#  'dionysianarbiter': 5,
#  'Bunnyhop': 3,
#  'thesyko56': 3,
#  'gabeerfan': 3,
#  'harpo111': 3,
#  'psugrad98': 3,
#  'Nutleybeer': 3,
#  'billzee': 3,
#  'iconoklaztor': 3,
#  'Redrover': 3,
#  'cokes': 3,
#  'barleyman': 3,
#  'kdog630': 5,
#  'mentor': 3,
#  'Southernbrew': 3,
#  'slvrmon82': 3,
#  'Mebuzzard': 3,
#  'kleing': 3,
#  'atigerlife': 3,
#  'GONZALOYANNA': 3,
#  'dasenebler': 3,
#  'gfreed': 3,
#  'dqrull': 3,
#  'JISurfer': 3,
#  'bigbelcher': 3,
#  'barefootbrewer': 3,
#  'July2Nov': 3,
#  'bruachan': 3,
#  'beals': 3,
#  'meatbeagle': 3,
#  'AaronHomoya': 3,
#  'Taelec': 3,
#  'dgallina': 3,
#  'scruffwhor': 3,
#  'rtratzlaff': 3,
#  'UncleFlip': 3,
#  'VoodooBrew': 3,
#  'wl0307': 5,
#  'rye726': 3,
#  'Gagnonsux': 3,
#  'shapudding': 3,
#  'BeerBuilder': 3,
#  'SilentSabre': 3,
#  'feloniousmonk': 3,
#  'Gusler': 3,
#  'mzwolinski': 3,
#  'UnionMade': 3,
#  'Happyhour': 3,
#  'crwills': 3,
#  'richdebs': 3,
#  'StevieW': 3,
#  'Zimbo': 3,
#  'cyrenaica': 3,
#  'plinythethirsty': 3,
#  'Sigmund': 5,
#  'tenesmus': 5,
#  'jdhilt': 3,
#  'ybnorml': 3,
#  'Brad007': 3,
#  'WonderWoman': 3,
#  'DarkerTheBetter': 3,
#  'arizcards': 3,
#  'bvillejohns': 5,
#  'BeerShark': 3,
#  'donnebaby': 5,
#  'dennis': 3,
#  'WoodBrew': 3,
#  'Nicadeamis': 5,
#  'huguey': 3,
#  'beerhobo22': 3,
#  'RickS95': 3,
#  'TLove': 3,
#  'SolomonGrundy': 3,
#  'Wisconsinality': 3,
#  'JoePat': 3,
#  'degerbah': 3,
#  'ThaBobfather': 3,
#  'Wheelinb': 3,
#  'OldYoda': 3,
#  'Ambiorix': 3,
#  'stewart124': 3,
#  'rapayn01': 3,
#  'Brew33': 3,
#  'johncampbell': 3,
#  'ABOWMan': 3,
#  'cnjohn19': 3,
#  'BillyBoysPie': 3,
#  'bigdeuce': 3,
#  'UA8': 3,
#  'bheilman': 3,
#  'lovindahops': 3,
#  'Fillpott': 3,
#  'nms1987': 3,
#  'daliandragon': 3,
#  'atsprings': 3,
#  'chinchill': 3,
#  'farrago': 3,
#  'TheKingofWichita': 3,
#  'injuredreserve': 3,
#  'Schwab': 3,
#  'mactrail': 5,
#  'goindownsouth': 3,
#  'bdupree': 3,
#  'Mississipping': 3,
#  'thegodfather2701': 3,
#  'TKempe': 5,
#  'Bierman9': 3,
#  'HappyHourHero': 3,
#  'TigerFan': 5,
#  'StJamesGate': 3,
#  'JohnfromDublin': 3,
#  'redjameskidd': 3,
#  'CuriousMonk': 3,
#  'HoosBrews': 3,
#  'CBlack85': 3,
#  'VncentLIFE': 3,
#  'samtallica': 3,
#  'syrupjoe': 3,
#  'lehows': 3,
#  'brewerburgundy': 3,
#  'GeoffRizzo': 3,
#  'Winter': 3,
#  'bditty187': 3,
#  'cosmicevan': 3,
#  'cstrong821': 5,
#  'Mypintishalffull': 3,
#  'gskitt': 3,
#  'Brianjames16': 3,
#  'brendan13': 3,
#  'bonbright7': 3,
#  'jeranbrews': 3,
#  'socon67': 3,
#  'Gmann': 3,
#  'phreshbeer': 5,
#  'SkunkWorks': 3,
#  'BBM': 3,
#  'Billolick': 3,
#  'iRoy': 3,
#  'steelerguy': 3,
#  'Parrotshake': 3,
#  'dgilks': 3,
#  'lacqueredmouse': 3,
#  'laituegonflable': 3,
#  'crusian': 5,
#  'ADZA': 3,
#  'yapi': 3,
#  'spicelab': 3,
#  'Ratman197': 5,
#  'joecast': 3,
#  'burnheartsMKE': 3,
#  'tsauce2': 3,
#  'dansmcd': 3,
#  'Macca': 3,
#  'champ103': 3,
#  'LSUPT': 3,
#  'wschmit': 3,
#  'TMoney2591': 3,
#  'crnipeter': 3,
#  'RblWthACoz': 3,
#  'NCBeernut': 3,
#  'thierrynantes': 5,
#  'DCon': 3,
#  'Figgy': 3,
#  'metaltec15': 3,
#  'orbitalr0x': 3,
#  'ndekke39': 3,
#  'betterbgood': 3,
#  'DannelB': 5,
#  'CampusCrew': 3,
#  'aquaderek': 3,
#  'ManofWax': 3,
#  'bloomy': 5,
#  'jdavin': 5,
#  'slicknuss': 5,
#  'grittybrews': 3,
#  'Akeen34': 5,
#  'BigJTrucker': 3,
#  'Norfawkers': 3,
#  'ardeano': 3,
#  'Bourre': 5,
#  'junjun': 3,
#  'Gorilla': 5,
#  'rustyhydrant217': 3,
#  'assurbanipaul': 3,
#  'SchmichaelJ': 3,
#  'stjaernstoft': 3,
#  'Beeromaniac': 5,
#  'Globetrotter': 5,
#  'JohnW': 3,
#  'rarbring': 3,
#  'soulgrowl': 3,
#  'drpimento': 3,
#  'atis': 5,
#  'valgalder': 5,
#  'CzechThisOut': 5,
#  'RedRocker5152': 3,
#  'gnoff': 5,
#  'BeerBeing': 3,
#  'FirstMan': 3,
#  'Quej': 3,
#  'JanM': 3,
#  'neenerzig': 3,
#  'akronzipfan': 3,
#  'drgonzo3705': 3,
#  'klewis': 3,
#  'Vierenner': 3,
#  'adamette': 3,
#  'adamg8504': 5,
#  'newyawker': 3,
#  'Boto': 3,
#  'mophie': 3,
#  'TheSevenDuffs': 3,
#  'Squelch': 3,
#  'lefty': 3,
#  'billshmeinke': 3,
#  'far333': 3,
#  'ChrisCage': 5,
#  'WJVII': 3,
#  'callmeclemens': 3,
#  'BavariaYeti': 5,
#  'BravoTwo': 3,
#  'dansteino': 3,
#  'theclaudius': 5,
#  'Luk13': 3,
#  'Beersignal': 3,
#  'Goldorak': 3,
#  'TurdFurgison': 3,
#  'raninator84': 3,
#  'paco1029384756': 3,
#  'cpetrone84': 3,
#  'MbpBugeye': 3,
#  'Pecorasc': 3,
#  'jampics2': 3,
#  'nlmartin': 3,
#  'FromTheRoad': 5,
#  'BeerVikingSailor': 3,
#  'imaguitargod': 3,
#  'KAP1356': 3,
#  'goblue3509': 3,
#  'heysuz': 3,
#  'BeerWanker': 2,
#  'Beaver13': 3,
#  'jamescain': 3,
#  'Durge': 3,
#  'DoubleSimcoe': 3,
#  'parris': 3,
#  'KansasBeerLover': 3,
#  'Dreadnaught33': 3,
#  'scotvega18': 3,
#  'Preismj': 3,
#  'output01x': 3,
#  'beergod1': 3,
#  'Sideswipe': 3,
#  'biglobo8971': 3,
#  'Arknot': 5,
#  'mjw1200': 3,
#  'b3shine': 3,
#  'superspak': 3,
#  'CaptCleveland': 3,
#  'JamnesCameron': 3,
#  'TheHoppiest': 3,
#  'pdoran10': 3,
#  'ne0m00re': 3,
#  'Lerxst': 3,
#  'fear025': 3,
#  'SykDoc': 3,
#  'kwjd': 3,
#  'mntlover': 3,
#  'alkemy': 3,
#  'TheDoodles': 5,
#  'Viciousknishs': 3,
#  'Trystero': 3,
#  'JayS2629': 3,
#  'Torgo': 3,
#  'bigfnjoe': 3,
#  'WwRGSwW': 3,
#  'steve8robin': 3,
#  'Onenote81': 3,
#  'nick76': 3,
#  'kbeals': 3,
#  'vrazionale': 3,
#  'wingman14': 3,
#  'csmiley': 3,
#  'nrbw23': 3,
#  'PorterLover83': 3,
#  'ATLbeerDog': 3,
#  'Phatz': 3,
#  'Grundle20': 3,
#  'jpm30': 3,
#  'muddyriverduck': 3,
#  'budsboy': 3,
#  'tr4nc3d': 3,
#  'GJ40': 3,
#  'babaracas': 3,
#  'joeyspit': 3,
#  'spwalshesq': 3,
#  'prsguitarsr4me': 3,
#  'dsw4b': 3,
#  'popery': 3,
#  'Jeffo': 3,
#  'jbphoto88': 3,
#  'mechamifune': 3,
#  'kimcgolf': 3,
#  'ricke': 3,
#  'redneckchugger': 3,
#  'aubuc1': 3,
#  'JasonA': 3,
#  'LauraAlberts': 3,
#  'RonfromJersey': 3,
#  'Zorro': 3,
#  'beerthulhu': 3,
#  'Foxman': 3,
#  'aerozeppl': 3,
#  'gameface23': 3,
#  'GatorBeerNerd': 3,
#  'DrJay': 3,
#  'Doomcifer': 3,
#  'gibby': 3,
#  'ABVerageJoe': 3,
#  'JTSbeerislife': 3,
#  'sgoodship': 3,
#  'tayner': 3,
#  'ffejherb': 3,
#  'stumac': 3,
#  'prototypic': 3,
#  'swizzlenuts': 3,
#  'RustyDiamond': 3,
#  'dsigmon': 3,
#  'BigBry': 3,
#  'jjayjaye': 3,
#  'brewdogmrb': 3,
#  'TheodorHerzl': 3,
#  'ncvbc': 3,
#  'Gehrig': 3,
#  'thartman': 3,
#  't0rin0': 5,
#  'Drewcifer': 3,
#  'dholway': 6,
#  'hustlesworth': 3,
#  'aepb1': 3,
#  'bosco7': 3,
#  'SPLITGRIN': 3,
#  'taez555': 3,
#  'churchillps': 3,
#  'paulthebeerguru': 3,
#  'emerge077': 3,
#  'lightindarkness': 3,
#  'sweethome': 3,
#  'ziggy13': 3,
#  'ppoitras': 3,
#  'Rhynes2': 3,
#  'mryuk': 3,
#  'Naugros': 3,
#  'McNealc31': 3,
#  'cameraman': 3,
#  'hrockefeller': 3,
#  'muddah37': 3,
#  'DevilDogBeer': 3,
#  'pwoods': 3,
#  'letsgopens': 3,
#  'Westsidethreat': 3,
#  'jlh8643': 3,
#  'bearcobb': 3,
#  'BeerTruth': 3,
#  'TheBierBand': 3,
#  'wagenvolks': 3,
#  'chimney': 3,
#  'cooncat': 3,
#  ...}

# %%
# obliczamy licznosci segmentow

def get_segment_sizes(segmentation):
    # ...
    segment_sizes = np.zeros(SEGMENTS_COUNT)
    for _, segment in segmentation.items():
        segment_sizes[segment] += 1
    
    return segment_sizes
    

get_segment_sizes(segmentation)
# Out:
# array([ 1447.,  2171.,  2382., 15692.,  1093.,  4294.,  1210.,   784.,
#          539.,   674.])

# %% [markdown]
# ## Część 4. - opisy segmentów

# %%
# obliczamy popularnosc styli w segmentach oraz w calej populacji
#  - czyli jak czesto kazdy ze styli wystepowal

def get_per_segment_styles_popularity(users_favourite_beers, beer_styles, segmentation, segments_count):
    beer_styles_per_segment = {i: defaultdict(lambda: 0) for i in range(segments_count)}
    # do tego slownika bedziemy sie odwolywac np. tak: beer_styles_per_segment[segment][style]
    
    for user, beers in users_favourite_beers.items():
        for beer in beers:
            beer_styles_per_segment[segmentation[user]][beer_styles[beer]] += 1
    
    return beer_styles_per_segment

def get_total_styles_popularity(beer_styles_per_segment):
    total_popularity = defaultdict(lambda: 0)
    # ...
    for _, styles in beer_styles_per_segment.items():
        for style, count in styles.items():
            total_popularity[style] += count
    return total_popularity

per_segment_styles_popularity = get_per_segment_styles_popularity(users_favourite_beers, beer_styles, segmentation, SEGMENTS_COUNT)
total_styles_popularity = get_total_styles_popularity(per_segment_styles_popularity)

total_styles_popularity
# Out:
# defaultdict(<function __main__.get_total_styles_popularity.<locals>.<lambda>()>,
#             {'American Amber / Red Ale': 27301,
#              'American IPA': 84529,
#              'American Strong Ale': 21493,
#              'American Double / Imperial IPA': 63326,
#              'American Black Ale': 8254,
#              'Schwarzbier': 6267,
#              'Russian Imperial Stout': 41038,
#              'Czech Pilsener': 7619,
#              'American Pale Ale (APA)': 40693,
#              'Belgian Strong Pale Ale': 21242,
#              'American Brown Ale': 16484,
#              'American Porter': 34604,
#              'Hefeweizen': 18951,
#              'Lambic - Fruit': 7300,
#              'English India Pale Ale (IPA)': 9095,
#              'Fruit / Vegetable Beer': 13821,
#              'English Dark Mild Ale': 1439,
#              'American Double / Imperial Stout': 38460,
#              'Belgian Strong Dark Ale': 26088,
#              'American Stout': 16177,
#              'Scottish Ale': 5436,
#              'Saison / Farmhouse Ale': 22644,
#              'American Pale Wheat Ale': 12103,
#              'Pumpkin Ale': 7914,
#              'Scotch Ale / Wee Heavy': 11629,
#              'American Wild Ale': 14036,
#              'American Pale Lager': 3437,
#              'Tripel': 20603,
#              'Quadrupel (Quad)': 13800,
#              'Flanders Oud Bruin': 3458,
#              'Rauchbier': 2456,
#              'Foreign / Export Stout': 4055,
#              'Weizenbock': 7034,
#              'Doppelbock': 14248,
#              'Winter Warmer': 11541,
#              'Dubbel': 13792,
#              'Milk / Sweet Stout': 8948,
#              'American Barleywine': 18285,
#              'Rye Beer': 7467,
#              'Witbier': 17755,
#              'Keller Bier / Zwickel Bier': 1827,
#              'Euro Dark Lager': 1695,
#              'Baltic Porter': 8407,
#              'Extra Special / Strong Bitter (ESB)': 10887,
#              'English Pale Ale': 12340,
#              'American Adjunct Lager': 7171,
#              'Kristalweizen': 1254,
#              'Flanders Red Ale': 4850,
#              'Belgian IPA': 9039,
#              'English Stout': 1748,
#              'Gueuze': 4756,
#              'Eisbock': 1926,
#              'Oatmeal Stout': 12877,
#              'Irish Red Ale': 4140,
#              'Herbed / Spiced Beer': 4372,
#              'English Barleywine': 8733,
#              'Dortmunder / Export Lager': 2772,
#              'Old Ale': 10016,
#              'Märzen / Oktoberfest': 13660,
#              'Munich Dunkel Lager': 4308,
#              'Kölsch': 4945,
#              'Bock': 5929,
#              'Maibock / Helles Bock': 6649,
#              'American Dark Wheat Ale': 728,
#              'Dunkelweizen': 4580,
#              'Euro Pale Lager': 4896,
#              'Bière de Garde': 4433,
#              'English Brown Ale': 11205,
#              'English Bitter': 5174,
#              'German Pilsener': 12444,
#              'Black & Tan': 953,
#              'Irish Dry Stout': 7587,
#              'Munich Helles Lager': 5010,
#              'Cream Ale': 2409,
#              'Belgian Pale Ale': 11919,
#              'Belgian Dark Ale': 3763,
#              'California Common / Steam Beer': 2585,
#              'Faro': 283,
#              'Vienna Lager': 5169,
#              'Bière de Champagne / Bière Brut': 555,
#              'American Amber / Red Lager': 4212,
#              'American Double / Imperial Pilsner': 3526,
#              'Smoked Beer': 1819,
#              'Wheatwine': 2300,
#              'Berliner Weissbier': 2311,
#              'Light Lager': 2658,
#              'American Malt Liquor': 689,
#              'Braggot': 521,
#              'Altbier': 4781,
#              'English Porter': 7733,
#              'American Blonde Ale': 6105,
#              'English Strong Ale': 2903,
#              'Low Alcohol Beer': 166,
#              'English Pale Mild Ale': 358,
#              'Lambic - Unblended': 841,
#              'Chile Beer': 834,
#              'Scottish Gruit / Ancient Herbed Ale': 1484,
#              'Sahti': 580,
#              'Euro Strong Lager': 487,
#              'Japanese Rice Lager': 360,
#              'Roggenbier': 326,
#              'Kvass': 111,
#              'Gose': 491,
#              'Happoshu': 57})

# %%
# przygotujmy dwa opisy segmentow - top N najpopularniejszych stylow w kazdym segmencie
#   oraz top N unikalnych - to samo, ale popularnosc w segmencie dzielimy przez laczna popularnosc
#   dla potrzeb wizualizacji w nastepnym kroku, zwroc slownik {segment_id -> {style_id -> frequency}}

def most_popular_styles_per_segment(per_segment_styles_popularity, N):
    # ...
    most_popular = {i: defaultdict(lambda: 0) for i in range(SEGMENTS_COUNT)}
    for segment, styles in per_segment_styles_popularity.items():
        most_popular[segment] = dict(sorted(styles.items(), key=lambda i: i[1], reverse=True)[:N])
        
    return most_popular

def most_distinctive_styles_per_segment(total_styles_popularity, per_segment_styles_popularity, N):
    # ...
    most_distinctive = {i: defaultdict(lambda: 0) for i in range(SEGMENTS_COUNT)}
    for segment, styles in per_segment_styles_popularity.items():
        styles = {key:value/total_styles_popularity[key] for key, value in styles.items()}
        most_distinctive[segment] = dict(sorted(styles.items(), key=lambda i: i[1])[:N])
        
    return most_distinctive
     
top_N = 50
most_popular = most_popular_styles_per_segment(per_segment_styles_popularity, top_N)
most_distinctive = most_distinctive_styles_per_segment(total_styles_popularity, per_segment_styles_popularity, top_N)

most_distinctive
# Out:
# {0: {'Euro Pale Lager': 0.0002042483660130719,
#   'American Double / Imperial Pilsner': 0.0002836074872376631,
#   'Maibock / Helles Bock': 0.00030079711234772146,
#   'Dortmunder / Export Lager': 0.00036075036075036075,
#   'Extra Special / Strong Bitter (ESB)': 0.0003674106732800588,
#   'California Common / Steam Beer': 0.00038684719535783365,
#   'Berliner Weissbier': 0.00043271311120726956,
#   'Wheatwine': 0.0004347826086956522,
#   'Herbed / Spiced Beer': 0.0004574565416285453,
#   'American Barleywine': 0.0004922067268252667,
#   'Old Ale': 0.0004992012779552715,
#   'Belgian Dark Ale': 0.0005314908317831517,
#   'Smoked Beer': 0.0005497526113249038,
#   'Fruit / Vegetable Beer': 0.0006511829824180595,
#   'Witbier': 0.0006758659532526049,
#   'American Amber / Red Lager': 0.0007122507122507123,
#   'Foreign / Export Stout': 0.0007398273736128237,
#   'Oatmeal Stout': 0.0007765783955890347,
#   'English Barleywine': 0.0008015573113477613,
#   'Rauchbier': 0.0008143322475570033,
#   'Bock': 0.0008433125316242199,
#   'Belgian Pale Ale': 0.0009228962161255138,
#   'Baltic Porter': 0.0009515879624122755,
#   'Irish Red Ale': 0.000966183574879227,
#   'American Brown Ale': 0.000970638194612958,
#   'English India Pale Ale (IPA)': 0.0009895547003848269,
#   'Pumpkin Ale': 0.0010108668182966893,
#   'English Brown Ale': 0.00107095046854083,
#   'Belgian Strong Dark Ale': 0.0011499540018399263,
#   'Vienna Lager': 0.0011607661056297156,
#   'Tripel': 0.0011648789011309032,
#   'Belgian Strong Pale Ale': 0.001176913661613784,
#   'Euro Dark Lager': 0.0011799410029498525,
#   'Rye Beer': 0.0012053033346725592,
#   'Kölsch': 0.0012133468149646107,
#   'Flanders Red Ale': 0.0012371134020618556,
#   'Cream Ale': 0.0012453300124533001,
#   'American Wild Ale': 0.0012824166429182104,
#   'German Pilsener': 0.0012857602057216328,
#   'Märzen / Oktoberfest': 0.0013177159590043923,
#   'English Bitter': 0.001352918438345574,
#   'Dubbel': 0.0013776102088167053,
#   'English Dark Mild Ale': 0.001389854065323141,
#   'Czech Pilsener': 0.001443759023493897,
#   'Flanders Oud Bruin': 0.0014459224985540775,
#   'English Pale Ale': 0.001458670988654781,
#   'Gueuze': 0.001471825063078217,
#   'Bière de Garde': 0.0015790660951951275,
#   'Scotch Ale / Wee Heavy': 0.001633846418436667,
#   'Bière de Champagne / Bière Brut': 0.0018018018018018018},
#  1: {'Scottish Gruit / Ancient Herbed Ale': 0.0006738544474393531,
#   'English Dark Mild Ale': 0.0006949270326615705,
#   'Wheatwine': 0.0008695652173913044,
#   'English Strong Ale': 0.0010334137099552187,
#   'Rauchbier': 0.0012214983713355048,
#   'American Wild Ale': 0.001353662011969222,
#   'English Brown Ale': 8.92458723784025e-05,
#   'Hefeweizen': 0.0001055353279510316,
#   'American Barleywine': 0.00010937927262783702,
#   'English Barleywine': 0.00011450818733539448,
#   'Baltic Porter': 0.00011894849530153443,
#   'American Adjunct Lager': 0.00013945056477478735,
#   'Doppelbock': 0.00014037057832678272,
#   'American Wild Ale': 0.00014249073810202338,
#   'Fruit / Vegetable Beer': 0.00014470732942623544,
#   'American Pale Wheat Ale': 0.00016524828554903743,
#   'Euro Pale Lager': 0.0002042483660130719,
#   'Dubbel': 0.00021751740139211136,
#   'American Porter': 0.0002311871459946827,
#   'American Double / Imperial Stout': 0.000234009360374415,
#   'German Pilsener': 0.00024108003857280618,
#   'Saison / Farmhouse Ale': 0.00030913266207383856,
#   'American Pale Ale (APA)': 0.0003440395153957683,
#   'Quadrupel (Quad)': 0.00036231884057971015,
#   'Light Lager': 0.0003762227238525207,
#   'Scotch Ale / Wee Heavy': 0.00042995958379912286,
#   'American Strong Ale': 0.000465267761596799,
#   'Oatmeal Stout': 0.0006212627164712278,
#   'American Amber / Red Ale': 0.0006226878136332002,
#   'Extra Special / Strong Bitter (ESB)': 0.0006429686782401029,
#   'Belgian Strong Pale Ale': 0.0007061481969682704,
#   'Witbier': 0.0007321881160236554,
#   'English Porter': 0.000775895512737618,
#   'Tripel': 0.0009221957967286317,
#   'Belgian Strong Dark Ale': 0.0010349586016559337,
#   'English Pale Ale': 0.00113452188006483,
#   'American IPA': 0.0011593654248837678,
#   'California Common / Steam Beer': 0.0011605415860735009,
#   'Foreign / Export Stout': 0.0012330456226880395,
#   'Schwarzbier': 0.001276527844263603,
#   'American Stout': 0.0013599554923657043,
#   'Berliner Weissbier': 0.0017308524448290783,
#   'Euro Strong Lager': 0.002053388090349076,
#   'Old Ale': 0.0020966453674121405,
#   'Russian Imperial Stout': 0.002266192309566743,
#   'American Double / Imperial IPA': 0.002289738811862426,
#   'Milk / Sweet Stout': 0.0025704067948144837,
#   'American Brown Ale': 0.0026085901480223245,
#   'Herbed / Spiced Beer': 0.0027447392497712718,
#   'Pumpkin Ale': 0.002906242102602982,
#   'Irish Red Ale': 0.003140096618357488,
#   'Irish Dry Stout': 0.009358112560959536}}

# %% [markdown]
# ## Część 5. - wizualizacja

# %%
# teraz mozemy zwizualizowac nasze segmentacje za pomoca word clouds
#   zauwaz, jak roznia sie obie metody opisow segmentow oraz opisy miedzy poszczegolnymi segmentami

def visualise_styles(most_popular, most_distinctive, segment_id):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    wordcloud1 = WordCloud(width = 1000, height = 750, random_state=42, background_color='black', colormap='Set2', collocations=False)
    wordcloud1.generate_from_frequencies(frequencies=most_popular[segment_id])
    ax1.imshow(wordcloud1, interpolation="bilinear")
    wordcloud2 = WordCloud(width = 1000, height = 750, random_state=42, background_color='black', colormap='Set2', collocations=False)
    wordcloud2.generate_from_frequencies(frequencies=most_distinctive[segment_id])
    ax2.imshow(wordcloud2, interpolation="bilinear")
    ax1.axis("off")
    ax2.axis("off")
    plt.show()
    
visualise_styles(most_popular, most_distinctive, 3)
